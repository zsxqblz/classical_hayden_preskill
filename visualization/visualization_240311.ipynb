# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import curve_fit
from collections import Counter

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# #### Rule 45 check nonlocal info loss
# Asites=1:6, Bsites=100, 1-6
#
# Asites=1:6, Bsites=0, 11-16

# %%
nAsites = 6
file_name = "../data/240311/240311_%d"%(0+nAsites)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)
 
raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(S_ave_arr.T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(S_std_arr.T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()

# %%
plt.figure(figsize=(6,5))
nAsites_l = np.arange(1,7,1)
for nAsites in nAsites_l:
    file_name = "../data/240311/240311_%d"%(0+nAsites)
    nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
    nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

    raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
    S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
    S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))
    plt.plot(nstep_l[:],S_ave_arr[-1,:])
    # plt.axhline(nAsites)
    plt.xlabel('time steps')
    plt.ylabel('entropy')

# %%
nAsites = 4
file_name = "../data/240311/240311_%d"%(10+nAsites)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)
 
raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(S_ave_arr.T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(S_std_arr.T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()

# %%
plt.figure(figsize=(6,5))
nAsites_l = np.arange(1,11,1)
for nAsites in nAsites_l:
    file_name = "../data/240311/240311_%d"%(10+nAsites)
    nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
    # nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)
    nmeas_l = np.arange(1,nAsites+1)

    raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
    S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
    S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))
    plt.plot(nstep_l[:],S_ave_arr[-1,:])
    # plt.hlines(nAsites,0,500)
    # plt.axhline(nAsites)
    plt.xlabel('time steps')
    plt.ylabel('entropy')

# %% [markdown]
# #### Rule 60 check nonlocal info loss
# Asites=1:6, Bsites=100, 21-26
#
# Asites=1:6, Bsites=0, 31-36

# %%
nAsites = 6
file_name = "../data/240311/240311_%d"%(20+nAsites)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)
 
raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(S_ave_arr.T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(S_std_arr.T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()

# %%
plt.figure(figsize=(6,5))
nAsites_l = np.arange(1,7,1)
for nAsites in nAsites_l:
    file_name = "../data/240311/240311_%d"%(20+nAsites)
    nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
    nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

    raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
    S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
    S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))
    plt.plot(nstep_l[:],S_ave_arr[-1,:])
    # plt.axhline(nAsites)
    plt.xlabel('time steps')
    plt.ylabel('entropy')

# %%
nAsites = 6
file_name = "../data/240311/240311_%d"%(30+nAsites)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)
 
raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(S_ave_arr.T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(S_std_arr.T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()

# %%
plt.figure(figsize=(6,5))
nAsites_l = np.arange(1,11,1)
for nAsites in nAsites_l:
    file_name = "../data/240311/240311_%d"%(30+nAsites)
    nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
    # nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)
    nmeas_l = np.arange(1,nAsites+1)

    raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
    S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
    S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))
    plt.plot(nstep_l[:],S_ave_arr[-1,:])
    plt.xlim([0,10])
    # plt.axhline(nAsites)
    plt.xlabel('time steps')
    plt.ylabel('entropy')
