# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import curve_fit
from collections import Counter

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# #### Rule 30 Noisy
# Asites=1, Bsites=10, steps=2000, pertb=0:0.05:1, MeasNoisy 1
#
# Asites=1, Bsites=100, steps=500, pertb=0:0.05:1, MeasNoisy 2
#
# Asites=1, Bsites=100, steps=500, pertb=0:0.05:1, RndMeasNoisy 3

# %%
file_name = "../data/240219/240219_1"
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)
pertb_l = np.loadtxt(file_name+'_scanz.csv',skiprows=1)
 
raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw[:,0].reshape((len(pertb_l),len(nmeas_l),len(nstep_l)))
S_std_arr = raw[:,1].reshape((len(pertb_l),len(nmeas_l),len(nstep_l)))
# S_ave_arr = raw[:,0].reshape((1,len(nmeas_l),len(nstep_l)))
# S_std_arr = raw[:,1].reshape((1,len(nmeas_l),len(nstep_l)))

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(S_ave_arr[2].T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(S_std_arr[2].T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()

# %%
plt.figure(figsize=(6,5))
for i in range(0,len(pertb_l),1):
    plt.plot(nstep_l,S_ave_arr[i][-1,:])
    # plt.xlim([0,200])
    plt.xscale('log')

# %%
plt.figure(figsize=(6,5))
for i in range(0,len(nstep_l),100):
    plt.plot(nmeas_l,S_ave_arr[0][:,i])
    # plt.xlim([0,200])
    # plt.xscale('log')

# %% [markdown]
# #

# %% [markdown]
# #### Rule 54 Stag Noisy
# Asites=1, Bsites=10, steps=2000, pertb=0:0.05:1, MeasNoisy 4

# %%
file_name = "../data/240219/240219_4"
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)
pertb_l = np.loadtxt(file_name+'_scanz.csv',skiprows=1)
 
raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw[:,0].reshape((len(pertb_l),len(nmeas_l),len(nstep_l)))
S_std_arr = raw[:,1].reshape((len(pertb_l),len(nmeas_l),len(nstep_l)))
# S_ave_arr = raw[:,0].reshape((1,len(nmeas_l),len(nstep_l)))
# S_std_arr = raw[:,1].reshape((1,len(nmeas_l),len(nstep_l)))

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(S_ave_arr[2].T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(S_std_arr[2].T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()

# %%
plt.figure(figsize=(6,5))
for i in range(0,len(pertb_l),1):
    plt.plot(nstep_l,S_ave_arr[i][-1,:])
    # plt.xlim([0,200])
    plt.xscale('log')

# %% [markdown]
# #### Rule F3 Stag Noisy
# Asites=1, Bsites=10, steps=2000, pertb=0:0.05:1, MeasNoisy 5

# %%
file_name = "../data/240219/240219_5"
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)
pertb_l = np.loadtxt(file_name+'_scanz.csv',skiprows=1)
 
raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw[:,0].reshape((len(pertb_l),len(nmeas_l),len(nstep_l)))
S_std_arr = raw[:,1].reshape((len(pertb_l),len(nmeas_l),len(nstep_l)))
# S_ave_arr = raw[:,0].reshape((1,len(nmeas_l),len(nstep_l)))
# S_std_arr = raw[:,1].reshape((1,len(nmeas_l),len(nstep_l)))

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(S_ave_arr[2].T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(S_std_arr[2].T[::-1,:],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()

# %%
plt.figure(figsize=(6,5))
for i in range(0,len(pertb_l),1):
    plt.plot(nstep_l,S_ave_arr[i][-1,:])
    # plt.xlim([0,200])
    plt.xscale('log')

# %% [markdown]
# #### Rule 30 Long time
# Asites = 1:10, Bsites = 9:0, nsteps=1024 6:15

# %%
nAsites = 5
file_name = "../data/240219/240219_%d"%(5+nAsites)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))

plt.rcParams["figure.figsize"] = (12,5)
plt.subplot(1,2,1)
plt.imshow(S_ave_arr.T[::-1,0:50],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(S_std_arr.T[::-1,0:50],aspect="auto",cmap="Oranges",extent=[nmeas_l[0],nmeas_l[-1],nstep_l[0],nstep_l[-1]])
plt.colorbar()

# %%
plt.figure(figsize=(6,5))
nAsites_l = np.arange(1,11,1)
for nAsites in nAsites_l:
    file_name = "../data/240219/240219_%d"%(5+nAsites)
    nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
    nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

    raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
    S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
    S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))
    plt.plot(S_ave_arr[-1,:])
