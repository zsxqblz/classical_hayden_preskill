# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import curve_fit
from collections import Counter

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# ## classical HP
# Asites=1:5, Bsites=100, rule 30 1-5
#
# Asites=1:5, Bsites=100, rule 110 6-10

# %%
nAsites = 1
file_idx = 18
file_name = "../data/240329/240329_%d"%(file_idx)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw.reshape((len(nmeas_l),len(nstep_l)))

plt.figure(figsize=(6,5))
plt.imshow(S_ave_arr.T[-1:0:-1,:],aspect="auto",cmap="Oranges",extent=[0,nmeas_l[-1],0,nstep_l[-1]],vmin=0,vmax=8)
cbar = plt.colorbar()
cbar.ax.set_ylabel("$S_D$")
plt.xlabel("$N_D$")
plt.ylabel("t")
print(np.max(S_ave_arr))
plt.tight_layout()
# Out:
# 6.851116025674559

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
# plt.plot(nmeas_l, S_ave_arr[:,-1],'*')
plt.plot(nmeas_l, 10-S_ave_arr[:,-1])
plt.plot(nmeas_l,10-10*nmeas_l/(1))
plt.yscale('log')
plt.plot()

plt.subplot(1,2,2)
plt.plot(nstep_l, S_ave_arr[50,:],'*-')

# %% [markdown]
# publication plot

# %%
plt.figure(figsize=(12,5))
nAsites = 8
file_idx = 0+nAsites
file_name = "../data/240329/240329_%d"%(file_idx)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw.reshape((len(nmeas_l),len(nstep_l)))

plt.subplot(1,2,1)
plt.plot(nmeas_l, S_ave_arr[:,-1])
# plt.yscale('log')
plt.subplot(1,2,2)
plt.plot(nstep_l, S_ave_arr[50,:],)

nAsites = 8
file_idx = 10+nAsites
file_name = "../data/240329/240329_%d"%(file_idx)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw.reshape((len(nmeas_l),len(nstep_l)))

plt.subplot(1,2,1)
plt.plot(nmeas_l, S_ave_arr[:,-1])
# plt.yscale('log')
plt.subplot(1,2,2)
plt.plot(nstep_l, S_ave_arr[50,:],)

plt.subplot(1,2,1)
plt.plot(nmeas_l,nmeas_l,"--")
plt.xlim([0,nmeas_l[-1]])
plt.ylim([0,10])
plt.xlabel("$N_D$")
plt.ylabel("$S_D$")
# Out:
# Text(0, 0.5, '$S_D$')

# %%
plt.figure(figsize=(5,5))
nAsites = 8
file_idx = 0+nAsites
file_name = "../data/240329/240329_%d"%(file_idx)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw.reshape((len(nmeas_l),len(nstep_l)))

plt.plot(nmeas_l, 8-S_ave_arr[:,-1])

nAsites = 8
file_idx = 10+nAsites
file_name = "../data/240329/240329_%d"%(file_idx)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw.reshape((len(nmeas_l),len(nstep_l)))

plt.plot(nmeas_l, 8-S_ave_arr[:,-1])


plt.yscale('log')
plt.plot(nmeas_l,1/2**(nmeas_l-10),"--")
plt.xlim([0,30])
plt.ylim([1e-3,10])
plt.xlabel("$N_D$")
plt.ylabel("$N_A-S_D$")
# Out:
# Text(0, 0.5, '$N_A-S_D$')

# %%
plt.figure(figsize=(10,5))
nAsites = 8
file_idx = 0+nAsites
file_name = "../data/240329/240329_%d"%(file_idx)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw.reshape((len(nmeas_l),len(nstep_l)))

plt.subplot(1,2,1)
plt.plot(nmeas_l, 8-np.average(S_ave_arr[:,-40:],axis=1))
# plt.yscale('log')
plt.subplot(1,2,2)
plt.plot(nstep_l, S_ave_arr[50,:],)

nAsites = 8
file_idx = 10+nAsites
file_name = "../data/240329/240329_%d"%(file_idx)
nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
S_ave_arr = raw.reshape((len(nmeas_l),len(nstep_l)))

plt.subplot(1,2,1)
plt.plot(nmeas_l, 8-S_ave_arr[:,-1])
plt.subplot(1,2,2)
plt.plot(nstep_l, S_ave_arr[50,:],)

plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(nmeas_l,1/2**(nmeas_l-8),"--")
plt.xlim([0,30])
plt.ylim([1e-3,10])
plt.xlabel("$N_D$")
plt.ylabel("$N_A-S_D$")
# Out:
# Text(0, 0.5, '$N_A-S_D$')

# %%
plt.figure(figsize=(5,5))

nAsites_l = np.arange(1,10)
max_S_l = []
for nAsites in nAsites_l:
    file_idx = 0+nAsites
    file_name = "../data/240329/240329_%d"%(file_idx)
    nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
    nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

    raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
    S_ave_arr = raw.reshape((len(nmeas_l),len(nstep_l)))
    max_S_l.append(np.max(S_ave_arr))

plt.plot(nAsites_l,max_S_l,'o')

nAsites_l = np.arange(1,10)
max_S_l = []
for nAsites in nAsites_l:
    file_idx = 10+nAsites
    file_name = "../data/240329/240329_%d"%(file_idx)
    nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
    nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

    raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
    S_ave_arr = raw.reshape((len(nmeas_l),len(nstep_l)))
    max_S_l.append(np.max(S_ave_arr))

plt.plot(nAsites_l,max_S_l,'*')


plt.plot(nAsites_l,nAsites_l,'--')
plt.xlabel("$N_A$")
plt.ylabel("max $S_D$")
# Out:
# Text(0, 0.5, 'max $S_D$')

# %% [markdown]
# ## Rule 30 OBC
# check global info loss
#
# Asites=2:10,Bsites=0, 42-50

# %%
plt.figure(figsize=(6,5))
cmap = mpl.colormaps['winter']
nAsites_l = np.arange(3,11,1)
for nAsites in nAsites_l:
    file_name = "../data/240329/240329_%d"%(40+nAsites)
    nstep_l = np.loadtxt(file_name+'_scanx.csv',skiprows=1)
    nmeas_l = np.loadtxt(file_name+'_scany.csv',skiprows=1)

    raw = np.loadtxt(file_name+'_data.csv',skiprows=1,delimiter=',')
    S_ave_arr = raw[:,0].reshape((len(nmeas_l),len(nstep_l)))
    S_std_arr = raw[:,1].reshape((len(nmeas_l),len(nstep_l)))
    plt.plot(nstep_l[:],S_ave_arr[-1,:],c=cmap((nAsites)/10))
    # plt.axhline(nAsites)
    plt.xlabel('t')
    plt.ylabel('$S_D$')
